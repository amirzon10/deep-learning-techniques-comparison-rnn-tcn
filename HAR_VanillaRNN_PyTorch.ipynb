# %%
# Importing required libraries
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import pickle
import os
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
# Set random seeds for reproducibility
seed = 42
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = True

# Check CUDA availability with diagnostics
print("PyTorch CUDA Diagnostics:")
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA version: {torch.version.cuda}")
print(f"cuDNN version: {torch.backends.cudnn.version()}")

if torch.cuda.is_available():
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
    print(f"Number of GPUs: {torch.cuda.device_count()}")
    device = torch.device("cuda")
    print(f"Using device: {device} ({torch.cuda.get_device_name(0)})")
else:
    print("⚠️  CUDA not available. PyTorch likely installed without GPU support.")
    print("Fix: Reinstall PyTorch with CUDA support from https://pytorch.org/get-started/locally/")
    device = torch.device("cpu")
    print(f"Falling back to: {device}")
# Out:
# PyTorch CUDA Diagnostics:
# PyTorch version: 2.7.1+cu118
# CUDA available: True
# CUDA version: 11.8
# cuDNN version: 90100
# GPU Name: NVIDIA GeForce RTX 4050 Laptop GPU
# Number of GPUs: 1
# Using device: cuda (NVIDIA GeForce RTX 4050 Laptop GPU)

# %% [markdown]
# # Dataset: Human Activity Recognition (HAR) Using Smartphones - Regression Task

# %% [markdown]
# ### Characteristics

# %%
# Load preprocessed HAR dataset
base_dir = 'c:/Users/deepa/Documents/Deeplearning CA/deep-learning-techniques-comparison-rnn-tcn'
preprocessed_dir = os.path.join(base_dir, 'preprocessed_data')

with open(os.path.join(preprocessed_dir, 'har.pkl'), 'rb') as f:
    har_data = pickle.load(f)

# Create dataframe from preprocessed data

X_har = pd.DataFrame(har_data['X_train_seq'].reshape(har_data['X_train_seq'].shape[0], -1))
y_har = pd.DataFrame(har_data['y_train_seq'], columns=['Activity'])
har_df = pd.concat([X_har, y_har], axis=1)
# Out:
# c:\Users\deepa\.conda\envs\Epochdev\Lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %% [markdown]
# Characteristic 1 & 2.

# %%
num_variables = har_df.shape[1]
num_records = har_df.shape[0]
print(f"Number of variables (columns): {num_variables}")
print(f"Number of records (rows): {num_records}\n")
# Out:
# Number of variables (columns): 71937
# Number of records (rows): 6083

# %% [markdown]
# Characteristic 3.

# %%
har_df.head(10)
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.128386  0.323476 -0.155819 -0.881550 -0.853728 -0.894421 -0.875293
# 1  0.071474  0.712859 -0.112055 -0.016436  0.659086  0.448000 -0.023957
# 2  0.026818  0.115813 -0.020394 -0.886205 -0.962082 -0.928645 -0.880366
# 3  0.036773  0.045976  0.031106 -0.883437 -0.959788 -0.952931 -0.876076
# 4  1.534668 -0.104699 -0.490683  0.887507  0.753239  0.920750  0.997032
# 5  0.012234  0.037183  0.019045 -0.885099 -0.949919 -0.927507 -0.878540
# 6  0.855014  0.675847  0.260423  0.684850  1.102681 -0.030534  0.638858
# 7  0.057822  0.027844  0.054731 -0.879617 -0.963418 -0.951383 -0.874356
# 8  0.923938  0.255270 -0.666762  0.417268  1.837391  0.419692  0.397247
# 9  0.793848 -0.619138 -0.288167  0.449243  1.007106  0.885075  0.543535
#
#           7         8         9  ...     71927     71928     71929     71930  \
# 0 -0.836702 -0.896562 -0.870903  ... -0.790477 -1.201235  0.704526 -1.538240
# ...

# %%
har_df.tail(10)
# Out:
#              0         1         2         3         4         5         6  \
# 6073 -0.266680  0.035590  0.950251  0.821771  1.408399  0.785370  0.792980
# 6074 -0.007576 -0.044619  0.166900 -0.820707 -0.700029 -0.808535 -0.838817
# 6075 -0.137142  0.274574  0.230548  0.881983  1.348917  1.662648  0.935857
# 6076  0.053639  0.099088  0.155217 -0.887959 -0.946501 -0.925687 -0.880507
# 6077 -0.075263 -0.966255 -0.062765  0.272165  0.840581  0.695924  0.285700
# 6078  0.061893  0.022961  0.030413 -0.888554 -0.963099 -0.951812 -0.881108
# 6079 -0.056435 -0.061585 -0.564301 -0.883635 -0.930654 -0.819801 -0.876338
# 6080 -1.738062 -0.051065 -0.648013  1.490055  1.332831  0.662517  1.425826
# 6081  0.087751  0.712232 -0.631746  1.587664  1.716913  2.556683  1.442893
# 6082 -0.183894 -0.032654  0.073494 -0.842126 -0.953403 -0.915456 -0.832980
#
#              7         8         9  ...     71927     71928     71929  \
# 6073  1.432464  0.708590  1.054000  ... -0.571136 -0.328057 -0.689381
# ...

# %%
print("Data types of each column:")
print(har_df.dtypes)
print("\n")
# Out:
# Data types of each column:
# 0           float64
# 1           float64
# 2           float64
# 3           float64
# 4           float64
#              ...
# 71932       float64
# 71933       float64
# 71934       float64
# 71935       float64
# Activity      int64
# Length: 71937, dtype: object

# %% [markdown]
# The HAR dataset contains 561 features extracted from accelerometer and gyroscope sensor signals. Key feature categories include:
# - Time domain body acceleration signals (tBodyAcc)
# - Time domain gravity acceleration signals (tGravityAcc)
# - Time domain body angular velocity signals (tBodyGyro)
# - Frequency domain signals (fBodyAcc, fBodyGyro)
# - Jerk signals and magnitude measurements
#
# All features are numerical continuous variables normalized to [-1, 1]. The target variable 'Activity' is treated as a continuous regression target, representing activity intensity levels from low (static activities) to high (dynamic activities).

# %% [markdown]
# Characteristic 4.

# %%
# Generate descriptive (summary) statistics for the first 10 features and target
print("Descriptive (summary) statistics (first 10 features):")
print(har_df.iloc[:, :10].describe())
print("\n")
print("Target variable distribution:")
print(har_df['Activity'].value_counts())
print("\n")
# Out:
# Descriptive (summary) statistics (first 10 features):
#                  0            1            2            3            4  \
# count  6083.000000  6083.000000  6083.000000  6083.000000  6083.000000
# mean      0.006898     0.007227    -0.014695     0.006176     0.009620
# std       0.948883     0.899224     0.926462     1.000173     1.003154
# min     -16.683233   -17.948246   -16.803062    -0.893864    -0.978941
# 25%      -0.165714    -0.185250    -0.235961    -0.876634    -0.931966
# 50%       0.041273     0.016350     0.006018    -0.757540    -0.618077
# 75%       0.213671     0.197323     0.207723     0.823102     0.916400
# max       6.002541    16.491152    19.945499     3.665112     3.019082
#
#                  5            6            7            8            9
# count  6083.000000  6083.000000  6083.000000  6083.000000  6083.000000
# mean      0.009916     0.005839     0.008366     0.008454     0.007701
# ...

# %% [markdown]
# Characteristics 5

# %%
# Check for and print the total count of missing values
missing_values = har_df.isnull().sum()
print("Missing values per column:")
print(missing_values[missing_values > 0])
if missing_values.sum() == 0:
    print("No missing values found.\n")
else:
    print("\n")

# Check for and print the total count of duplicate rows
duplicate_rows = har_df.duplicated().sum()
print(f"Total count of duplicate rows: {duplicate_rows}\n")

print(f"Number of features: {num_variables - 1}")
print(f"Number of classes: {har_df['Activity'].nunique()}\n")
# Out:
# Missing values per column:
# Series([], dtype: int64)
# No missing values found.
#
# Total count of duplicate rows: 0
#
# Number of features: 71936
# Number of classes: 6

# %% [markdown]
# Characteristics 6.

# %% [markdown]
# Balancing assessment: The target variable is now continuous numerical values, indicating a regression problem. The preprocessed data has already been properly prepared and split appropriately.

# %% [markdown]
# ### Dataset preprocessing:
# * Features are already extracted and normalized
# * Data is loaded from preprocessed pickle file
# * Sequences are pre-created with proper train/val/test splits

# %%
# Load preprocessed sequences directly
X_train_seq = har_data['X_train_seq']
y_train_seq = har_data['y_train_seq']

X_val_seq = har_data['X_val_seq']
y_val_seq = har_data['y_val_seq']

X_test_seq = har_data['X_test_seq']
y_test_seq = har_data['y_test_seq']

print(f"Preprocessed HAR sequences loaded:")
print(f"\nSequence shape: {X_train_seq.shape}")
print(f"Number of training samples: {X_train_seq.shape[0]}")
print(f"Timesteps per sequence: {X_train_seq.shape[1]}")
print(f"Features per timestep: {X_train_seq.shape[2]}\n")
# Out:
# Preprocessed HAR sequences loaded:
#
# Sequence shape: (6083, 128, 562)
# Number of training samples: 6083
# Timesteps per sequence: 128
# Features per timestep: 562

# %%
print(f"Training set:")
print(f"  X shape: {X_train_seq.shape}, y shape: {y_train_seq.shape}")
print(f"\nValidation set:")
print(f"  X shape: {X_val_seq.shape}, y shape: {y_val_seq.shape}")
print(f"\nTest set:")
print(f"  X shape: {X_test_seq.shape}, y shape: {y_test_seq.shape}\n")
# Out:
# Training set:
#   X shape: (6083, 128, 562), y shape: (6083,)
#
# Validation set:
#   X shape: (2028, 128, 562), y shape: (2028,)
#
# Test set:
#   X shape: (1932, 128, 562), y shape: (1932,)

# %%
# Normalize target variable for regression
target_scaler = MinMaxScaler(feature_range=(0, 1))
y_train_seq = target_scaler.fit_transform(y_train_seq.reshape(-1, 1)).flatten()
y_val_seq = target_scaler.transform(y_val_seq.reshape(-1, 1)).flatten()
y_test_seq = target_scaler.transform(y_test_seq.reshape(-1, 1)).flatten()

# Convert to PyTorch tensors (FloatTensor for regression)
X_train_seq = torch.FloatTensor(X_train_seq).to(device)
y_train_seq = torch.FloatTensor(y_train_seq).unsqueeze(1).to(device)

X_val_seq = torch.FloatTensor(X_val_seq).to(device)
y_val_seq = torch.FloatTensor(y_val_seq).unsqueeze(1).to(device)

X_test_seq = torch.FloatTensor(X_test_seq).to(device)
y_test_seq = torch.FloatTensor(y_test_seq).unsqueeze(1).to(device)

print("PyTorch tensors created:")
print(f"  X_train_seq: {X_train_seq.shape}")
print(f"  y_train_seq: {y_train_seq.shape}")
print(f"  X_test_seq: {X_test_seq.shape}")
print(f"  y_test_seq: {y_test_seq.shape}\n")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 3
#       1 # Normalize target variable for regression
#       2 target_scaler = MinMaxScaler(feature_range=(0, 1))
# ----> 3 y_train_seq = target_scaler.fit_transform(y_train_seq.reshape(-1, 1)).flatten()
#       4 y_val_seq = target_scaler.transform(y_val_seq.reshape(-1, 1)).flatten()
#       5 y_test_seq = target_scaler.transform(y_test_seq.reshape(-1, 1)).flatten()
#
# File c:\Users\deepa\.conda\envs\Epochdev\Lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
# ...

# %% [markdown]
# ## Technique: Vanilla RNN

# %%
class VanillaRNN(nn.Module):
    def __init__(self, input_size, hidden_units):
        super(VanillaRNN, self).__init__()
        # Powerful bidirectional multi-layer LSTM
        self.lstm1 = nn.LSTM(input_size, hidden_units, num_layers=2, batch_first=True, bidirectional=True, dropout=0.3)
        self.lstm2 = nn.LSTM(hidden_units * 2, hidden_units, num_layers=1, batch_first=True, bidirectional=True)
        
        # Attention mechanism
        self.attention = nn.MultiheadAttention(hidden_units * 2, num_heads=8, batch_first=True, dropout=0.2)
        
        self.dropout = nn.Dropout(0.4)
        
        # Dense regression layers - avoid batch norm issues
        self.fc1 = nn.Linear(hidden_units * 2, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 128)
        self.fc4 = nn.Linear(128, 64)
        self.fc5 = nn.Linear(64, 1)
        
        self.elu = nn.ELU()
    
    def forward(self, x):
        # Multi-layer LSTM with bidirectional
        lstm_out1, _ = self.lstm1(x)
        lstm_out2, _ = self.lstm2(lstm_out1)
        
        # Self-attention
        attn_out, _ = self.attention(lstm_out2, lstm_out2, lstm_out2)
        lstm_combined = lstm_out2 + 0.3 * attn_out
        
        # Global average pooling
        out = torch.mean(lstm_combined, dim=1)
        
        # Dense layers
        out = self.fc1(out)
        out = self.elu(out)
        out = self.dropout(out)
        
        out = self.fc2(out)
        out = self.elu(out)
        out = self.dropout(out)
        
        out = self.fc3(out)
        out = self.elu(out)
        out = self.dropout(out)
        
        out = self.fc4(out)
        out = self.elu(out)
        out = self.dropout(out)
        
        out = self.fc5(out)
        return out

# %%
seq_length = X_train_seq.shape[1]
num_features = X_train_seq.shape[2]

hidden_units = 128  # Significantly increased
epochs = 100  # More training
batch_size = 32  # Smaller for better gradient updates
learning_rate = 0.001

model = VanillaRNN(num_features, hidden_units).to(device)
# Huber loss is more robust than MSE for regression
criterion = nn.HuberLoss(delta=0.1, reduction='mean')
optimizer = optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=1e-5)
# Cosine annealing scheduler for better convergence
scheduler = optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=2, eta_min=1e-5)

print(model)
print(f"\nModel Parameters: {sum(p.numel() for p in model.parameters())}")
print(f"Epochs: {epochs}, Batch Size: {batch_size}, LR: {learning_rate}")
print(f"Loss Function: Huber Loss (delta=0.1) - More robust for regression")
# Out:
# VanillaRNN(
#   (lstm1): LSTM(562, 128, num_layers=2, batch_first=True, dropout=0.3, bidirectional=True)
#   (lstm2): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (attention): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#   )
#   (dropout): Dropout(p=0.4, inplace=False)
#   (fc1): Linear(in_features=256, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=64, bias=True)
#   (fc5): Linear(in_features=64, out_features=1, bias=True)
#   (elu): ELU(alpha=1.0)
# )
#
# Model Parameters: 2066433
# Epochs: 100, Batch Size: 32, LR: 0.001
# Loss Function: Huber Loss (delta=0.1) - More robust for regression

# %%
# Create data loaders with improved settings
train_dataset = TensorDataset(X_train_seq, y_train_seq)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=False, drop_last=True)

val_dataset = TensorDataset(X_val_seq, y_val_seq)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=False)

train_losses = []
val_losses = []
val_r2_list = []
best_val_loss = float('inf')
best_r2 = float('-inf')
patience_counter = 0
early_stop_patience = 15

import time
start_time = time.time()

for epoch in range(epochs):
    model.train()
    train_loss = 0.0
    
    for X_batch, y_batch in train_loader:
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        
        optimizer.zero_grad()
        loss.backward()
        # Aggressive gradient clipping
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=2.0)
        optimizer.step()
        
        train_loss += loss.item()
    
    train_losses.append(train_loss / len(train_loader))
    
    # Validation phase
    model.eval()
    val_loss = 0.0
    val_r2_scores = []
    
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            val_loss += loss.item()
            
            # Calculate R² for validation
            y_true = y_batch.cpu().numpy()
            y_pred = outputs.cpu().numpy()
            ss_res = np.sum((y_true - y_pred) ** 2)
            ss_tot = np.sum((y_true - np.mean(y_true)) ** 2)
            r2 = 1 - (ss_res / ss_tot) if ss_tot > 0 else 0
            val_r2_scores.append(r2)
    
    avg_val_loss = val_loss / len(val_loader)
    avg_val_r2 = np.mean(val_r2_scores)
    val_losses.append(avg_val_loss)
    val_r2_list.append(avg_val_r2)
    
    # Learning rate scheduler step
    scheduler.step()
    
    # Early stopping based on R² improvement
    if avg_val_r2 > best_r2:
        best_r2 = avg_val_r2
        best_val_loss = avg_val_loss
        patience_counter = 0
        torch.save(model.state_dict(), 'best_rnn_har.pth')
    else:
        patience_counter += 1
    
    if (epoch + 1) % 10 == 0:
        print(f'Epoch [{epoch+1}/{epochs}], Train Loss: {train_losses[-1]:.6f}, Val Loss: {avg_val_loss:.6f}, Val R²: {avg_val_r2:.4f}')
    
    if patience_counter >= early_stop_patience:
        print(f"Early stopping at epoch {epoch+1}")
        break

elapsed_time = time.time() - start_time
print(f"\nTraining completed in {elapsed_time:.2f} seconds")
print(f"Best Validation Loss: {best_val_loss:.6f}")
print(f"Best Validation R²: {best_r2:.4f}")

# %%
# Load best model and evaluate
model.load_state_dict(torch.load('best_rnn_har.pth'))
model.eval()

with torch.no_grad():
    y_pred = model(X_test_seq).cpu().numpy()
    y_test_np = y_test_seq.cpu().numpy()

# Calculate regression metrics
mse = mean_squared_error(y_test_np, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_np, y_pred)
r2 = r2_score(y_test_np, y_pred)

print(f"\n{'='*50}")
print(f"PyTorch Vanilla RNN - HAR Regression Results")
print(f"{'='*50}")
print(f"Mean Squared Error (MSE): {mse:.6f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.6f}")
print(f"Mean Absolute Error (MAE): {mae:.6f}")
print(f"R² Score: {r2:.4f}")
print(f"\nModel explains {r2*100:.2f}% of the variance in the target variable")
print(f"R² Score: {r2:.4f}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[34], line 2
#       1 # Load best model and evaluate
# ----> 2 model.load_state_dict(torch.load('best_rnn_har.pth'))
#       3 model.eval()
#       5 with torch.no_grad():
#
# File c:\Users\deepa\.conda\envs\Epochdev\Lib\site-packages\torch\nn\modules\module.py:2593, in Module.load_state_dict(self, state_dict, strict, assign)
#    2585         error_msgs.insert(
#    2586             0,
#    2587             "Missing key(s) in state_dict: {}. ".format(
#    2588                 ", ".join(f'"{k}"' for k in missing_keys)
#    2589             ),
#    2590         )
#    2592 if len(error_msgs) > 0:
# -> 2593     raise RuntimeError(
#    2594         "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2595             self.__class__.__name__, "\n\t".join(error_msgs)
#    2596         )
#    2597     )
# ...

# %%
# Visualization
plt.figure(figsize=(18, 5))

# Plot 1: Training and Validation Loss
plt.subplot(1, 3, 1)
plt.plot(train_losses, label='Train Loss (MSE)', linewidth=2, marker='o')
plt.plot(val_losses, label='Val Loss (MSE)', linewidth=2, marker='s')
plt.title('Model Loss Over Epochs', fontsize=12, fontweight='bold')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.legend()
plt.grid(True, alpha=0.3)

# Plot 2: Predictions vs Actual (Scatter plot)
plt.subplot(1, 3, 2)
plt.scatter(y_test_np, y_pred, alpha=0.6, edgecolors='k', linewidth=0.5)
plt.plot([y_test_np.min(), y_test_np.max()], [y_test_np.min(), y_test_np.max()], 'r--', lw=2, label='Perfect Prediction')
plt.title(f'Predicted vs Actual (R²={r2:.4f})', fontsize=12, fontweight='bold')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.grid(True, alpha=0.3)

# Plot 3: Residuals (Errors)
plt.subplot(1, 3, 3)
residuals = y_test_np - y_pred
plt.scatter(y_pred, residuals, alpha=0.6, edgecolors='k', linewidth=0.5)
plt.axhline(y=0, color='r', linestyle='--', lw=2)
plt.title('Residuals Plot', fontsize=12, fontweight='bold')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals (Actual - Predicted)')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"\n{'='*50}")
print(f"Training Summary:")
print(f"{'='*50}")
print(f"Final Train Loss: {train_losses[-1]:.6f}")
print(f"Final Val Loss: {val_losses[-1]:.6f}")
print(f"Best Val Loss: {best_val_loss:.6f}")
print(f"Improvement: {((val_losses[0] - best_val_loss) / val_losses[0] * 100):.2f}%")
# Out:
# ...
# Training Summary:
# ...
# Final Train Loss: 0.114254
# Final Val Loss: 0.126914
# Best Val Loss: 0.118537
# Improvement: 0.05%
